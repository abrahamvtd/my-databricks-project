# %%
# %sql
CREATE CATALOG IF NOT EXISTS medallion_project;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS medallion_project.bronze;
CREATE SCHEMA IF NOT EXISTS medallion_project.silver;
CREATE SCHEMA IF NOT EXISTS medallion_project.gold;

# %%
# %sql
select * from medallion_project.bronze
