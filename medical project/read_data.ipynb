# %%
columns = [
    "emp_id","full_name","age","gender","department",
    "salary","hire_date","rating","manager_id","location"
]
schema_name = "cognizant"
uc_name = "demo_catalog1"
table_name = "employee"

spark.sql(
    f"CREATE SCHEMA IF NOT EXISTS {uc_name}.{schema_name}"
)

df = spark.createDataFrame(
    data,
    columns
)

df.write.mode("overwrite").option("mergeSchema", "true").saveAsTable(f"{uc_name}.{schema_name}.{table_name}")

# %%
df=spark.sql(f"select * from {uc_name}.{schema_name}.{table_name}")
df_filter=df.filter((df.salary>50000) & (df.rating>4.5))
