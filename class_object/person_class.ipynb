# %%
class person:
    def __init__(self,name,age,occupation,salary):
        self.name=name
        self.age=age
        self.occupation=occupation
        self.salary=salary
    def details(self):
        return(f"Hi Name:{self.name}!, your Age:{self.age}, Occupation:{self.occupation}, and Salary:{self.salary}")
